# %%
import pandas as pd

# %%
df = pd.read_csv('../Tables/ML_Test_pgd_checked.csv')
df.head()
# Out:
#    Unnamed: 0  movie_id                                     title  \
# 0           0       671  Harry Potter and the Philosopher's Stone
# 1           1       557                                Spider-Man
# 2           2       672   Harry Potter and the Chamber of Secrets
# 3           3       673  Harry Potter and the Prisoner of Azkaban
# 4           4       674       Harry Potter and the Goblet of Fire
#
#   release_date  movie_popularity  vote_average  vote_count     budget  \
# 0   2001-11-16           268.472           7.9       21429  125000000
# 1   2002-05-01           480.954           7.2       14421  139000000
# 2   2002-11-13           246.027           7.7       17294  100000000
# 3   2004-05-31           225.882           8.0       17001  130000000
# 4   2005-11-16           244.428           7.8       16341  150000000
#
#      revenue ratings  actor_popularity_mean  director_popularity_mean  \
# 0  976475550      PG               2.993965                     2.566
# ...

# %%
for test in df['studios']:
    for studio in eval(test):
        print(studio)
# Out:
# Warner Bros. Pictures
#   Heyday Films
#   Other
# Other
#   Columbia Pictures
#   Sony Pictures
#   Other
#   Marvel Entertainment
# Warner Bros. Pictures
#   Heyday Films
#   Other
# Warner Bros. Pictures
#   Other
#   Heyday Films
# Warner Bros. Pictures
#   Heyday Films
#   Other
# Columbia Pictures
#   Other
#   Marvel Studios
# Warner Bros. Pictures
#   Heyday Films
# Other
#   Columbia Pictures
#   Other
#   Sony Pictures
# Other
#   Other
# Other
#   Other
# Warner Bros. Pictures
#   Heyday Films
# Other
#   Other
# Warner Bros. Pictures
#   Heyday Films
# Warner Bros. Pictures
#   Heyday Films
# Other
#   New Line Cinema
#   Other
# Marvel Studios
# Marvel Entertainment
#   Other
#   Sony Pictures
#   Columbia Pictures
# Marvel Entertainment
#   Columbia Pictures
#   Other
#   Sony Pictures
# Other
# Other
#   Other
# Other
#   Other
# Marvel Studios
#   Columbia Pictures
#   Pascal Pictures
#   Other
#   Sony Pictures
# Other
#   Walt Disney Pictures
# Marvel Studios
# ...

# %%
test = pd.read_csv('../Tables/Test_ML.csv')
test.head()
# Out:
#   release_date  movie_popularity  vote_average  vote_count     budget  \
# 0   2021-09-01          5884.885           7.9        3428  150000000
# 1   2021-09-30          5797.863           7.0        2452  110000000
# 2   2021-09-29          3366.389           7.6        2075  242000000
# 3   2021-11-03          1746.171           7.1        1170  200000000
# 4   2021-09-01          1710.038           7.2         956   14000000
#
#      revenue rating                                      genres  \
# 0  430238384  PG-13          ['Action', 'Adventure', 'Fantasy']
# 1  454000000  PG-13  ['Science Fiction', 'Action', 'Adventure']
# 2  734000000  PG-13         ['Adventure', 'Action', 'Thriller']
# 3  336000000  PG-13  ['Action', 'Adventure', 'Science Fiction']
# 4   19000000      R                        ['Romance', 'Drama']
#
#                                              studios  actor_popularity  \
# 0                                 ['Marvel Studios']          6.738895
# ...

# %%
for test in test['studios']:
    for studio in test:
        print(studio)
# Out:
# [
# '
# M
# a
# r
# v
# e
# l
#
# S
# t
# u
# d
# i
# o
# s
# '
# ]
# [
# '
# M
# a
# r
# v
# e
# l
#
# E
# n
# t
# e
# r
# t
# a
# i
# n
# m
# e
# n
# t
# '
# ,
#
# '
#
# P
# a
# s
# c
# a
# l
#
# P
# i
# c
# t
# u
# r
# e
# s
# '
# ,
#
# '
#
# C
# o
# l
# u
# m
# b
# i
# a
#
# P
# i
# c
# t
# u
# r
# e
# s
# '
# ,
#
# '
#
# S
# o
# n
# y
#
# P
# i
# c
# t
# u
# r
# e
# s
# '
# ,
#
# '
#
# O
# t
# h
# e
# r
# '
# ]
# [
# '
# O
# t
# h
# e
# r
# '
# ,
#
# '
#
# M
# e
# t
# r
# o
# -
# G
# o
# l
# d
# w
# y
# n
# -
# M
# a
# y
# e
# r
# '
# ,
#
# '
#
# O
# t
# h
# e
# r
# '
# ,
#
# '
#
# U
# n
# i
# v
# e
# r
# s
# a
# l
#
# P
# i
# c
# t
# u
# r
# e
# s
# '
# ]
# [
# '
# M
# a
# r
# v
# e
# l
#
# S
# t
# u
# d
# i
# o
# s
# '
# ]
# [
# '
# O
# t
# h
# e
# r
# '
# ,
#
# '
#
# O
# t
# h
# e
# r
# '
# ,
#
# '
#
# O
# t
# h
# e
# r
# '
# ,
#
# '
#
# O
# t
# h
# e
# r
# '
# ,
#
# '
#
# O
# t
# h
# e
# r
# '
# ]
# [
# '
# O
# t
# h
# e
# r
# '
# ]
# [
# '
# O
# t
# h
# e
# r
# '
# ,
#
# '
# ...
