# %%
import pandas as pd
import requests
from API_Key import api_key
titleNid = pd.read_csv("../Tables/titleNid.csv")

# %%
famous_actors = pd.DataFrame()
id_for_movie = []

for movie_id in titleNid['movie_id']:
    movie = requests.get(f'https://api.themoviedb.org/3/movie/{movie_id}/credits?api_key={api_key}&language=en-US').json()
    for popular in movie['cast']:
            famous_actors = famous_actors.append(popular,ignore_index = True)
            id_for_movie.append(movie_id)

# %%
famous_actors["movie_id"] = id_for_movie
famous_actors
# Out:
#        adult  cast_id                         character  \
# 0        0.0      1.0               Eddie Brock / Venom
# 1        0.0      7.0           Cletus Kasady / Carnage
# 2        0.0      9.0                       Anne Weying
# 3        0.0     14.0  Frances Louise Barrison / Shriek
# 4        0.0     13.0                     Dr. Dan Lewis
# ...      ...      ...                               ...
# 82236    0.0     36.0                        Sonia Bern
# 82237    0.0     79.0                        Eric Addey
# 82238    0.0     84.0              Chicken Inn Customer
# 82239    0.0     85.0                            Lawyer
# 82240    0.0     86.0                          Reporter
#
#                       credit_id  gender         id known_for_department  \
# 0      5c5b3ebfc3a3683cc6885550     2.0     2524.0               Acting
# 1      5c86bc069251410d3616ff8e     2.0    57755.0               Acting
# 2      5d4b75510021340013269639     1.0     1812.0               Acting
# 3      5daa557cb2681f0014915771     1.0     2038.0               Acting
# 4      5d8d512979b3d4001f894708     2.0    81316.0               Acting
# ...                         ...     ...        ...                  ...
# 82236  52fe44c0c3a36847f80a7f95     1.0    56104.0               Acting
# 82237  56abaeb89251417e29003081     2.0  1252814.0               Acting
# 82238  57c7046a9251417387004906     2.0  1672707.0               Acting
# 82239  589860da925141458200218e     2.0    93848.0               Acting
# 82240  59721b32c3a3686f7c0336c3     0.0  1402629.0               Acting
#
#                     name  order      original_name  popularity  \
# 0              Tom Hardy    0.0          Tom Hardy      43.673
# 1        Woody Harrelson    1.0    Woody Harrelson      20.428
# 2      Michelle Williams    2.0  Michelle Williams      11.080
# 3          Naomie Harris    3.0      Naomie Harris      10.711
# 4             Reid Scott    4.0         Reid Scott       2.677
# ...                  ...    ...                ...         ...
# 82236     Sharon Maughan   22.0     Sharon Maughan       1.530
# 82237       Angus Wright   23.0       Angus Wright       1.620
# 82238      Dylan Charles   24.0      Dylan Charles       0.980
# 82239       Julian Firth   25.0       Julian Firth       2.126
# 82240     Antony Gabriel   26.0     Antony Gabriel       0.600
#
#                            profile_path  movie_id
# 0      /sOi4UZxflV07E7QXUaJTHROGlPU.jpg    580489
# 1      /igxYDQBbTEdAqaJxaW6ffqswmUU.jpg    580489
# 2      /sXTP6wlqIDz1tDGLU3DFbklSTpq.jpg    580489
# 3      /pDFs4gSeKSyIF8PditvtHqAq687.jpg    580489
# 4      /kBAeDUDA7XJRXFLGNALlpE5d3lA.jpg    580489
# ...                                 ...       ...
# 82236  /zcIJ4RcKk2v5KGRL4E3aKjisoBq.jpg      8848
# 82237  /sjpzYOulNc0CyxGTj7H39DN6uge.jpg      8848
# 82238                              None      8848
# 82239  /3PrG3eOAXFRvzZm5jLHwYwCs8RT.jpg      8848
# 82240  /zd9tycc0hJaotZ8s8viNmFDnMZW.jpg      8848
#
# [82241 rows x 13 columns]

# %%
famous_actors = famous_actors.rename(columns = {"id": "actor_id",'popularity': 'actor_popularity'})

# %%
famous_actors_cleaned = famous_actors[['name','actor_id','gender','character','actor_popularity','movie_id']]
famous_actors_cleaned
# Out:
#                     name   actor_id  gender                         character  \
# 0              Tom Hardy     2524.0     2.0               Eddie Brock / Venom
# 1        Woody Harrelson    57755.0     2.0           Cletus Kasady / Carnage
# 2      Michelle Williams     1812.0     1.0                       Anne Weying
# 3          Naomie Harris     2038.0     1.0  Frances Louise Barrison / Shriek
# 4             Reid Scott    81316.0     2.0                     Dr. Dan Lewis
# ...                  ...        ...     ...                               ...
# 82236     Sharon Maughan    56104.0     1.0                        Sonia Bern
# 82237       Angus Wright  1252814.0     2.0                        Eric Addey
# 82238      Dylan Charles  1672707.0     2.0              Chicken Inn Customer
# 82239       Julian Firth    93848.0     2.0                            Lawyer
# 82240     Antony Gabriel  1402629.0     0.0                          Reporter
#
#        actor_popularity  movie_id
# 0                43.673    580489
# 1                20.428    580489
# 2                11.080    580489
# 3                10.711    580489
# 4                 2.677    580489
# ...                 ...       ...
# 82236             1.530      8848
# 82237             1.620      8848
# 82238             0.980      8848
# 82239             2.126      8848
# 82240             0.600      8848
#
# [82241 rows x 6 columns]

# %%
directors = pd.DataFrame()
director_movie_id = []

for movie_id in titleNid['movie_id']:
    movie  = requests.get(f'https://api.themoviedb.org/3/movie/{movie_id}/credits?api_key={api_key}&language=en-US').json()
    for crew_member in movie['crew']:
        if crew_member['job'] == "Director":
            directors = directors.append(crew_member, ignore_index=True)
            director_movie_id.append(movie_id)

# %%
directors['movie_id'] = director_movie_id
directors = directors.rename(columns={'id': 'director_id', 'popularity': 'director_popularity'})
directors
# Out:
#       adult                 credit_id department  gender  director_id  \
# 0       0.0  5e866a52a5743d00180fe64e  Directing     2.0       1333.0
# 1       0.0  5c8965e39251410cf7c195f6  Directing     2.0    1144604.0
# 2       0.0  5ba362e80e0a265e50015bba  Directing     2.0      87257.0
# 3       0.0  6191c7c48e8d30004519318c  Directing     1.0    1395183.0
# 4       0.0  5bb93c4d0e0a2634f7018330  Directing     2.0      17825.0
# ...     ...                       ...        ...     ...          ...
# 2079    0.0  52fe4b769251416c751039f9  Directing     2.0      53333.0
# 2080    0.0  52fe43779251416c7501167d  Directing     2.0      65390.0
# 2081    0.0  52fe44ecc3a36847f80b2163  Directing     2.0      20629.0
# 2082    0.0  52fe44ecc3a36847f80b2169  Directing     2.0      57433.0
# 2083    0.0  52fe44c0c3a36847f80a7ef1  Directing     2.0      21370.0
#
#            job known_for_department                   name  \
# 0     Director               Acting            Andy Serkis
# 1     Director            Directing  Destin Daniel Cretton
# 2     Director            Directing     Cary Joji Fukunaga
# 3     Director            Directing             Chloé Zhao
# 4     Director            Directing             Shawn Levy
# ...        ...                  ...                    ...
# 2079  Director            Directing          John Hillcoat
# 2080  Director            Directing          Scott Kalvert
# 2081  Director            Directing          George Miller
# 2082  Director            Directing         George Ogilvie
# 2083  Director            Directing        Roger Donaldson
#
#               original_name  director_popularity  \
# 0               Andy Serkis               11.123
# 1     Destin Daniel Cretton                1.830
# 2        Cary Joji Fukunaga                3.413
# 3                Chloé Zhao                2.558
# 4                Shawn Levy                5.383
# ...                     ...                  ...
# 2079          John Hillcoat                1.380
# 2080          Scott Kalvert                0.600
# 2081          George Miller                3.142
# 2082         George Ogilvie                0.600
# 2083        Roger Donaldson                2.393
#
#                           profile_path  movie_id
# 0     /2aJLwOQK50Lx7PvIHGW1GMytTOL.jpg    580489
# 1     /6pOwxAXGsaqjlJmAdz9k3UArBdS.jpg    566525
# 2     /qhrtYCUM2NEaqVP3oB7vqkOTpx0.jpg    370172
# 3     /4Zmu4uigEtq5qAwJKQZW5e2QhDg.jpg    524434
# 4     /b1ulkCHz8biG87LjLQQiMCebEZo.jpg    550988
# ...                                ...       ...
# 2079  /doH9hSWTBcPJhX7QzxhseKQWbqT.jpg    146198
# 2080                              None     10474
# 2081  /eUzusS4Q8lOdlyjxQ777pf9oLuu.jpg      9355
# 2082                              None      9355
# 2083  /pPFxPo05qMvZSJ3Rs3YwD3tcUvb.jpg      8848
#
# [2084 rows x 12 columns]

# %%
director_clean = directors[['name','director_id','gender','director_popularity','movie_id']]
director_clean
# Out:
#                        name  director_id  gender  director_popularity  \
# 0               Andy Serkis       1333.0     2.0               11.123
# 1     Destin Daniel Cretton    1144604.0     2.0                1.830
# 2        Cary Joji Fukunaga      87257.0     2.0                3.413
# 3                Chloé Zhao    1395183.0     1.0                2.558
# 4                Shawn Levy      17825.0     2.0                5.383
# ...                     ...          ...     ...                  ...
# 2079          John Hillcoat      53333.0     2.0                1.380
# 2080          Scott Kalvert      65390.0     2.0                0.600
# 2081          George Miller      20629.0     2.0                3.142
# 2082         George Ogilvie      57433.0     2.0                0.600
# 2083        Roger Donaldson      21370.0     2.0                2.393
#
#       movie_id
# 0       580489
# 1       566525
# 2       370172
# 3       524434
# 4       550988
# ...        ...
# 2079    146198
# 2080     10474
# 2081      9355
# 2082      9355
# 2083      8848
#
# [2084 rows x 5 columns]

# %%
famous_actors_cleaned.to_csv("../Tables/Actors.csv", index = False)
director_clean.to_csv("../Tables/Directors.csv", index = False)
