# %%
import pandas as pd
import requests
from API_Key import api_key
titleNid = pd.read_csv("../Tables/titleNid.csv")

# %%
famous_actors = pd.DataFrame()
id_for_movie = []

for movie_id in titleNid['movie_id']:
    movie = requests.get(f'https://api.themoviedb.org/3/movie/{movie_id}/credits?api_key={api_key}&language=en-US').json()
    for popular in movie['cast']:
            famous_actors = famous_actors.append(popular,ignore_index = True)
            id_for_movie.append(movie_id)

# %%
famous_actors["movie_id"] = id_for_movie
famous_actors
# Out:
#       adult  cast_id                     character                 credit_id  \
# 0       0.0     11.0             Shaun / Shang-Chi  5d33b7e66a300b2f7ea6bc88
# 1       0.0     12.0                      Xu Wenwu  5d33c5fc2f8d094522dbaf68
# 2       0.0     10.0                     Katy Chen  5d33b71fcaab6d0b29a8a566
# 3       0.0     61.0                    Xu Xialing  602b041de72fe8003c101fca
# 4       0.0     54.0                       Ying Li  5f5a4014ec0c580035a40140
# ...     ...      ...                           ...                       ...
# 3813    0.0    179.0  Yoga Instructor (uncredited)  59cbd287c3a368770e0120e3
# 3814    0.0    180.0                     Bodyguard  59cbd2a4c3a368776e014603
# 3815    0.0    181.0  Yoga Instructor (uncredited)  59cbd3d99251412bb3013797
# 3816    0.0    182.0        Vato Punk (uncredited)  59cbd502c3a368770e01232a
# 3817    0.0    183.0           Goldie (uncredited)  59cbd561c3a3687761014697
#
#       gender         id known_for_department                 name  order  \
# 0        2.0  1489211.0               Acting             Simu Liu    0.0
# 1        2.0     1337.0               Acting  Tony Leung Chiu-wai    1.0
# 2        1.0  1625558.0               Acting            Awkwafina    2.0
# 3        1.0  2979464.0               Acting        Meng'er Zhang    3.0
# 4        1.0   123701.0               Acting            Fala Chen    4.0
# ...      ...        ...                  ...                  ...    ...
# 3813     2.0  1009255.0               Acting          Jason Trost   92.0
# 3814     1.0  1597880.0                 Crew       Tricia Trotter   93.0
# 3815     1.0  1496350.0               Acting     Janna VanHeertum   94.0
# 3816     2.0   174560.0               Acting        Peter Vasquez   95.0
# 3817     1.0    36072.0               Acting          Holly Weber   96.0
#
#             original_name  popularity                      profile_path  \
# 0                Simu Liu      25.916  /zrJjYjOYzDj7eY9oiHAoz8Yh0yk.jpg
# 1     Tony Leung Chiu-wai      35.415  /nQbSQAws5BdakPEB5MtiqWVeaMV.jpg
# 2               Awkwafina      33.139  /l5AKkg3H1QhMuXmTTmq1EyjyiRb.jpg
# 3           Meng'er Zhang      20.521  /yMiYThzzkeVSsUI2sxh3iIWmMTy.jpg
# 4               Fala Chen       8.171  /1eoEj3umXbxUkTXb5c7bmC3EUTh.jpg
# ...                   ...         ...                               ...
# 3813          Jason Trost       1.400  /x8kFqGcGTZsfi77yehuNff0J8po.jpg
# 3814       Tricia Trotter       0.600  /lnw9VoS4f5UTf34ii2DMaxzndr5.jpg
# 3815     Janna VanHeertum       0.600  /u2nyxsbcf36wkWk7O4QqDj1d5qP.jpg
# 3816        Peter Vasquez       1.007  /um4hvNIImwCSU0RlVkHvWk7jaMB.jpg
# 3817          Holly Weber       0.959  /qsoCBT574Oj7n6mP7u6lWRag1pt.jpg
#
#       movie_id
# 0       566525
# 1       566525
# 2       566525
# 3       566525
# 4       566525
# ...        ...
# 3813     15092
# 3814     15092
# 3815     15092
# 3816     15092
# 3817     15092
#
# [3818 rows x 13 columns]

# %%
famous_actors = famous_actors.rename(columns = {"id": "actor_id",'popularity': 'actor_popularity'})

# %%
famous_actors_cleaned = famous_actors[['name','actor_id','gender','character','actor_popularity','movie_id']]
famous_actors_cleaned
# Out:
#                      name   actor_id  gender                     character  \
# 0                Simu Liu  1489211.0     2.0             Shaun / Shang-Chi
# 1     Tony Leung Chiu-wai     1337.0     2.0                      Xu Wenwu
# 2               Awkwafina  1625558.0     1.0                     Katy Chen
# 3           Meng'er Zhang  2979464.0     1.0                    Xu Xialing
# 4               Fala Chen   123701.0     1.0                       Ying Li
# ...                   ...        ...     ...                           ...
# 3813          Jason Trost  1009255.0     2.0  Yoga Instructor (uncredited)
# 3814       Tricia Trotter  1597880.0     1.0                     Bodyguard
# 3815     Janna VanHeertum  1496350.0     1.0  Yoga Instructor (uncredited)
# 3816        Peter Vasquez   174560.0     2.0        Vato Punk (uncredited)
# 3817          Holly Weber    36072.0     1.0           Goldie (uncredited)
#
#       actor_popularity  movie_id
# 0               25.916    566525
# 1               35.415    566525
# 2               33.139    566525
# 3               20.521    566525
# 4                8.171    566525
# ...                ...       ...
# 3813             1.400     15092
# 3814             0.600     15092
# 3815             0.600     15092
# 3816             1.007     15092
# 3817             0.959     15092
#
# [3818 rows x 6 columns]

# %%
directors = pd.DataFrame()
director_movie_id = []

for movie_id in titleNid['movie_id']:
    movie  = requests.get(f'https://api.themoviedb.org/3/movie/{movie_id}/credits?api_key={api_key}&language=en-US').json()
    for crew_member in movie['crew']:
        if crew_member['job'] == "Director":
            directors = directors.append(crew_member, ignore_index=True)
            director_movie_id.append(movie_id)

# %%
directors['movie_id'] = director_movie_id
directors = directors.rename(columns={'id': 'director_id', 'popularity': 'director_popularity'})
directors
# Out:
#     adult                 credit_id department  gender  director_id       job  \
# 0     0.0  5c8965e39251410cf7c195f6  Directing     2.0    1144604.0  Director
# 1     0.0  5e866a52a5743d00180fe64e  Directing     2.0       1333.0  Director
# 2     0.0  5ba362e80e0a265e50015bba  Directing     2.0      87257.0  Director
# 3     0.0  6191c7c48e8d30004519318c  Directing     1.0    1395183.0  Director
# 4     0.0  5f6488921684f70036430cbe  Directing     1.0    1448492.0  Director
# ..    ...                       ...        ...     ...          ...       ...
# 75    0.0  5bfdd88f92514110800386b9  Directing     1.0    1795072.0  Director
# 76    0.0  5c2b62020e0a2655f238d898  Directing     2.0      49903.0  Director
# 77    0.0  52fe4871c3a368484e0f87a1  Directing     2.0     132876.0  Director
# 78    0.0  52fe46389251416c7507134b  Directing     2.0      20192.0  Director
# 79    0.0  52fe46389251416c75071345  Directing     2.0      20193.0  Director
#
#    known_for_department                   name          original_name  \
# 0             Directing  Destin Daniel Cretton  Destin Daniel Cretton
# 1                Acting            Andy Serkis            Andy Serkis
# 2             Directing     Cary Joji Fukunaga     Cary Joji Fukunaga
# 3             Directing             Chloé Zhao             Chloé Zhao
# 4             Directing        Castille Landon        Castille Landon
# ..                  ...                    ...                    ...
# 75            Directing            Nia DaCosta            Nia DaCosta
# 76            Directing               Tim Hill               Tim Hill
# 77            Directing            Brad Peyton            Brad Peyton
# 78              Writing           Brian Taylor           Brian Taylor
# 79              Writing         Mark Neveldine         Mark Neveldine
#
#     director_popularity                      profile_path  movie_id
# 0                 5.119  /6pOwxAXGsaqjlJmAdz9k3UArBdS.jpg    566525
# 1                13.077  /2aJLwOQK50Lx7PvIHGW1GMytTOL.jpg    580489
# 2                 4.167  /qhrtYCUM2NEaqVP3oB7vqkOTpx0.jpg    370172
# 3                 2.397  /4Zmu4uigEtq5qAwJKQZW5e2QhDg.jpg    524434
# 4                 2.580  /s1oXtmqyG9X0uDfiU5HidPB6BJx.jpg    744275
# ..                  ...                               ...       ...
# 75                0.600  /nf19k7N3HqNDKsOkmyquNhgMidf.jpg    565028
# 76                2.717  /jJ4UQBlQ71aJzU75ZxnO5gdTbnj.jpg    400160
# 77                1.425  /fJFxUT4CSUz047vlXdEBYIQjjFO.jpg     72545
# 78                1.333  /1TXxgF48STiUb3F9cp1L5iEx5Pb.jpg     15092
# 79                1.543  /lgmXPChEiXBSzroCSZS5XNqaZJF.jpg     15092
#
# [80 rows x 12 columns]

# %%
director_clean = directors[['name','director_id','gender','director_popularity','movie_id']]
director_clean
# Out:
#                      name  director_id  gender  director_popularity  movie_id
# 0   Destin Daniel Cretton    1144604.0     2.0                5.119    566525
# 1             Andy Serkis       1333.0     2.0               13.077    580489
# 2      Cary Joji Fukunaga      87257.0     2.0                4.167    370172
# 3              Chloé Zhao    1395183.0     1.0                2.397    524434
# 4         Castille Landon    1448492.0     1.0                2.580    744275
# ..                    ...          ...     ...                  ...       ...
# 75            Nia DaCosta    1795072.0     1.0                0.600    565028
# 76               Tim Hill      49903.0     2.0                2.717    400160
# 77            Brad Peyton     132876.0     2.0                1.425     72545
# 78           Brian Taylor      20192.0     2.0                1.333     15092
# 79         Mark Neveldine      20193.0     2.0                1.543     15092
#
# [80 rows x 5 columns]

# %%
famous_actors_cleaned.to_csv("../Tables/Actors.csv", index = False)
director_clean.to_csv("../Tables/Directors.csv", index = False)
