# %%
import pandas as pd
import requests
from API_Key import api_key
titleNid = pd.read_csv("../Tables/titleNid.csv")

# %%
famous_actors = pd.DataFrame()
id_for_movie = []

for movie_id in titleNid['movie_id']:
    movie = requests.get(f'https://api.themoviedb.org/3/movie/{movie_id}/credits?api_key={api_key}&language=en-US').json()
    for popular in movie['cast']:
            famous_actors = famous_actors.append(popular,ignore_index = True)
            id_for_movie.append(movie_id)

# %%
famous_actors["movie_id"] = id_for_movie
famous_actors
# Out:
#       adult  cast_id                         character  \
# 0       0.0     11.0                 Shaun / Shang-Chi
# 1       0.0     12.0                          Xu Wenwu
# 2       0.0     10.0                         Katy Chen
# 3       0.0     61.0                        Xu Xialing
# 4       0.0     54.0                           Ying Li
# ...     ...      ...                               ...
# 4077    0.0    136.0     Tony Stark Usher (uncredited)
# 4078    0.0    147.0  Stark Expo Attendee (uncredited)
# 4079    0.0    168.0                    VIP Expo Guest
# 4080    0.0    169.0                Guard (uncredited)
# 4081    0.0    186.0             Expo Fan (uncredited)
#
#                      credit_id  gender         id known_for_department  \
# 0     5d33b7e66a300b2f7ea6bc88     2.0  1489211.0               Acting
# 1     5d33c5fc2f8d094522dbaf68     2.0     1337.0               Acting
# 2     5d33b71fcaab6d0b29a8a566     1.0  1625558.0               Acting
# 3     602b041de72fe8003c101fca     1.0  2979464.0               Acting
# 4     5f5a4014ec0c580035a40140     1.0   123701.0               Acting
# ...                        ...     ...        ...                  ...
# 4077  52fe43339251416c750074ed     2.0  1122811.0               Acting
# 4078  54e7e9fc9251412eb8000c7e     2.0  1429470.0               Acting
# 4079  5f74e9c7d40d4c0038693f41     1.0  2798404.0               Acting
# 4080  5fc412844d6791003dda137c     2.0     9466.0               Acting
# 4081  61293ce00d9f5a002c52a72f     2.0    13922.0               Acting
#
#                         name  order           original_name  popularity  \
# 0                   Simu Liu    0.0                Simu Liu      24.572
# 1        Tony Leung Chiu-wai    1.0     Tony Leung Chiu-wai      40.255
# 2                  Awkwafina    2.0               Awkwafina      42.485
# 3              Meng'er Zhang    3.0           Meng'er Zhang      25.809
# 4                  Fala Chen    4.0               Fala Chen      11.653
# ...                      ...    ...                     ...         ...
# 4077  Peter Sebastian Wrobel  109.0  Peter Sebastian Wrobel       0.600
# 4078       Nick W. Nicholson  111.0       Nick W. Nicholson       0.600
# 4079           Kristin Quick  112.0           Kristin Quick       0.694
# 4080             Matt McColm  113.0             Matt McColm       4.376
# 4081              Seth Green  114.0              Seth Green       4.565
#
#                           profile_path  movie_id
# 0     /zrJjYjOYzDj7eY9oiHAoz8Yh0yk.jpg    566525
# 1     /nQbSQAws5BdakPEB5MtiqWVeaMV.jpg    566525
# 2     /l5AKkg3H1QhMuXmTTmq1EyjyiRb.jpg    566525
# 3     /yMiYThzzkeVSsUI2sxh3iIWmMTy.jpg    566525
# 4     /1eoEj3umXbxUkTXb5c7bmC3EUTh.jpg    566525
# ...                                ...       ...
# 4077                              None     10138
# 4078                              None     10138
# 4079                              None     10138
# 4080  /9SlVkQdWGURamicfGScV8BJNs2M.jpg     10138
# 4081  /l4No5Eu6j0U80hCIkaSn17AOWrj.jpg     10138
#
# [4082 rows x 13 columns]

# %%
famous_actors = famous_actors.rename(columns = {"id": "actor_id",'popularity': 'actor_popularity'})

# %%
famous_actors_cleaned = famous_actors[['name','actor_id','gender','character','actor_popularity','movie_id']]
famous_actors_cleaned
# Out:
#                         name   actor_id  gender  \
# 0                   Simu Liu  1489211.0     2.0
# 1        Tony Leung Chiu-wai     1337.0     2.0
# 2                  Awkwafina  1625558.0     1.0
# 3              Meng'er Zhang  2979464.0     1.0
# 4                  Fala Chen   123701.0     1.0
# ...                      ...        ...     ...
# 4077  Peter Sebastian Wrobel  1122811.0     2.0
# 4078       Nick W. Nicholson  1429470.0     2.0
# 4079           Kristin Quick  2798404.0     1.0
# 4080             Matt McColm     9466.0     2.0
# 4081              Seth Green    13922.0     2.0
#
#                              character  actor_popularity  movie_id
# 0                    Shaun / Shang-Chi            24.572    566525
# 1                             Xu Wenwu            40.255    566525
# 2                            Katy Chen            42.485    566525
# 3                           Xu Xialing            25.809    566525
# 4                              Ying Li            11.653    566525
# ...                                ...               ...       ...
# 4077     Tony Stark Usher (uncredited)             0.600     10138
# 4078  Stark Expo Attendee (uncredited)             0.600     10138
# 4079                    VIP Expo Guest             0.694     10138
# 4080                Guard (uncredited)             4.376     10138
# 4081             Expo Fan (uncredited)             4.565     10138
#
# [4082 rows x 6 columns]

# %%
directors = pd.DataFrame()
director_movie_id = []

for movie_id in titleNid['movie_id']:
    movie  = requests.get(f'https://api.themoviedb.org/3/movie/{movie_id}/credits?api_key={api_key}&language=en-US').json()
    for crew_member in movie['crew']:
        if crew_member['job'] == "Director":
            directors = directors.append(crew_member, ignore_index=True)
            director_movie_id.append(movie_id)

# %%
directors['movie_id'] = director_movie_id
directors = directors.rename(columns={'id': 'director_id', 'popularity': 'director_popularity'})
directors
# Out:
#     adult                 credit_id department  gender  director_id       job  \
# 0     0.0  5c8965e39251410cf7c195f6  Directing     2.0    1144604.0  Director
# 1     0.0  5ba362e80e0a265e50015bba  Directing     2.0      87257.0  Director
# 2     0.0  5e866a52a5743d00180fe64e  Directing     2.0       1333.0  Director
# 3     0.0  6191c7c48e8d30004519318c  Directing     1.0    1395183.0  Director
# 4     0.0  58920db99251412dd10093b4  Directing     2.0     137427.0  Director
# ..    ...                       ...        ...     ...          ...       ...
# 79    0.0  541bece00e0a2638e7000eb2  Directing     2.0      55252.0  Director
# 80    0.0  52fe4d859251416c91119095  Directing     2.0    1179066.0  Director
# 81    0.0  5f0cd91913a32000357fe6d7  Directing     2.0      19271.0  Director
# 82    0.0  5f0cd90f81c7be0033f7e757  Directing     2.0      19272.0  Director
# 83    0.0  52fe43329251416c750072b1  Directing     2.0      15277.0  Director
#
#    known_for_department                   name          original_name  \
# 0             Directing  Destin Daniel Cretton  Destin Daniel Cretton
# 1             Directing     Cary Joji Fukunaga     Cary Joji Fukunaga
# 2                Acting            Andy Serkis            Andy Serkis
# 3             Directing             Chloé Zhao             Chloé Zhao
# 4             Directing       Denis Villeneuve       Denis Villeneuve
# ..                  ...                    ...                    ...
# 79            Directing             Tim Miller             Tim Miller
# 80            Directing               Wes Ball               Wes Ball
# 81            Directing          Anthony Russo          Anthony Russo
# 82            Directing              Joe Russo              Joe Russo
# 83               Acting            Jon Favreau            Jon Favreau
#
#     director_popularity                      profile_path  movie_id
# 0                 4.245  /6pOwxAXGsaqjlJmAdz9k3UArBdS.jpg    566525
# 1                 7.496  /qhrtYCUM2NEaqVP3oB7vqkOTpx0.jpg    370172
# 2                 8.680  /2aJLwOQK50Lx7PvIHGW1GMytTOL.jpg    580489
# 3                 2.038  /4Zmu4uigEtq5qAwJKQZW5e2QhDg.jpg    524434
# 4                 8.809  /zdDx9Xs93UIrJFWYApYR28J8M6b.jpg    438631
# ..                  ...                               ...       ...
# 79                1.943  /dCyBYwhO76j5wA96HPb6k5xk2Le.jpg    293660
# 80                3.269  /zVPXrhuAxYAWlwDEWCaqeUPycFx.jpg    198663
# 81                3.015  /fIa5wXK7MHAquhefTr3TcnZiYy8.jpg    271110
# 82                3.657  /679Os4tbY1YsU01KdLhM1NPXNWu.jpg    271110
# 83                8.665  /8MtRRnEHaBSw8Ztdl8saXiw1egP.jpg     10138
#
# [84 rows x 12 columns]

# %%
director_clean = directors[['name','director_id','gender','director_popularity','movie_id']]
director_clean
# Out:
#                      name  director_id  gender  director_popularity  movie_id
# 0   Destin Daniel Cretton    1144604.0     2.0                4.245    566525
# 1      Cary Joji Fukunaga      87257.0     2.0                7.496    370172
# 2             Andy Serkis       1333.0     2.0                8.680    580489
# 3              Chloé Zhao    1395183.0     1.0                2.038    524434
# 4        Denis Villeneuve     137427.0     2.0                8.809    438631
# ..                    ...          ...     ...                  ...       ...
# 79             Tim Miller      55252.0     2.0                1.943    293660
# 80               Wes Ball    1179066.0     2.0                3.269    198663
# 81          Anthony Russo      19271.0     2.0                3.015    271110
# 82              Joe Russo      19272.0     2.0                3.657    271110
# 83            Jon Favreau      15277.0     2.0                8.665     10138
#
# [84 rows x 5 columns]

# %%
famous_actors_cleaned.to_csv("../Tables/Actors.csv", index = False)
director_clean.to_csv("../Tables/Directors.csv", index = False)
