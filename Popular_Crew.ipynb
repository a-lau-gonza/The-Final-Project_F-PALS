# %%
import pandas as pd
import requests
from API_Key import api_key
titleNid = pd.read_csv("Tables/titleNid.csv")

# %%
famous_actors = pd.DataFrame()
id_for_movie = []

for movie_id in titleNid['movie_id']:
    movie = requests.get(f'https://api.themoviedb.org/3/movie/{movie_id}/credits?api_key={api_key}&language=en-US').json()
    for popular in movie['cast']:
        if popular["popularity"] >=10:
            famous_actors = famous_actors.append(popular,ignore_index = True)
            id_for_movie.append(movie_id)

# %%
famous_actors["movie_id"] = id_for_movie
famous_actors
# Out:
#      adult  cast_id          character                 credit_id  gender  \
# 0      0.0     11.0  Shaun / Shang-Chi  5d33b7e66a300b2f7ea6bc88     2.0
# 1      0.0     12.0           Xu Wenwu  5d33c5fc2f8d094522dbaf68     2.0
# 2      0.0     10.0          Katy Chen  5d33b71fcaab6d0b29a8a566     1.0
# 3      0.0     61.0         Xu Xialing  602b041de72fe8003c101fca     1.0
# 4      0.0     54.0            Ying Li  5f5a4014ec0c580035a40140     1.0
# ..     ...      ...                ...                       ...     ...
# 437    0.0     12.0          Hua Mulan  5a1f27efc3a3680b930821c6     1.0
# 438    0.0     15.0        The Emperor  5acfa5ef9251413b39001d5c     2.0
# 439    0.0     20.0      Beros (voice)  60f3743c4c25920046b1f9cc     1.0
# 440    0.0      3.0    Desmond T. Doss  55b9d30892514123d8003c55     2.0
# 441    0.0      4.0    Sergeant Howell  55b9d31ec3a3684aed003f78     2.0
#
#             id known_for_department                 name  order  \
# 0    1489211.0               Acting             Simu Liu    0.0
# 1       1337.0               Acting  Tony Leung Chiu-wai    1.0
# 2    1625558.0               Acting            Awkwafina    2.0
# 3    2979464.0               Acting        Meng'er Zhang    3.0
# 4     123701.0               Acting            Fala Chen    4.0
# ..         ...                  ...                  ...    ...
# 437   122503.0               Acting            Liu Yifei    0.0
# 438     1336.0               Acting               Jet Li    2.0
# 439  1250465.0               Acting           Mariya Ise   10.0
# 440    37625.0               Acting      Andrew Garfield    0.0
# 441     4937.0               Acting         Vince Vaughn    2.0
#
#            original_name  popularity                      profile_path  \
# 0               Simu Liu      29.914  /zrJjYjOYzDj7eY9oiHAoz8Yh0yk.jpg
# 1    Tony Leung Chiu-wai      44.166  /nQbSQAws5BdakPEB5MtiqWVeaMV.jpg
# 2              Awkwafina      45.392  /l5AKkg3H1QhMuXmTTmq1EyjyiRb.jpg
# 3          Meng'er Zhang      21.879  /yMiYThzzkeVSsUI2sxh3iIWmMTy.jpg
# 4              Fala Chen      10.809  /1eoEj3umXbxUkTXb5c7bmC3EUTh.jpg
# ..                   ...         ...                               ...
# 437            Liu Yifei      11.235  /cL6JccAYqiZQEAIEFObEUC9LTt7.jpg
# 438               Jet Li      12.942  /7d4hgOzFW7CWPcE92eTSEFRSObC.jpg
# 439           Mariya Ise      10.340  /tQWlgrlQ70biWdg7x9E75CtwsuD.jpg
# 440      Andrew Garfield      33.885  /zEuvOPafRv1TQnOj9gxlbrWJgml.jpg
# 441         Vince Vaughn      10.579  /A9fJ88dfXZGpgFTnQIK0bOtjMrj.jpg
#
#      movie_id
# 0      566525
# 1      566525
# 2      566525
# 3      566525
# 4      566525
# ..        ...
# 437    337401
# 438    337401
# 439    768744
# 440    324786
# 441    324786
#
# [442 rows x 13 columns]

# %%
famous_actors = famous_actors.rename(columns = {"id": "actor_id",'popularity': 'actor_popularity'})

# %%
famous_actors_cleaned = famous_actors[['name','actor_id','gender','character','actor_popularity','movie_id']]
famous_actors_cleaned
# Out:
#                     name   actor_id  gender          character  \
# 0               Simu Liu  1489211.0     2.0  Shaun / Shang-Chi
# 1    Tony Leung Chiu-wai     1337.0     2.0           Xu Wenwu
# 2              Awkwafina  1625558.0     1.0          Katy Chen
# 3          Meng'er Zhang  2979464.0     1.0         Xu Xialing
# 4              Fala Chen   123701.0     1.0            Ying Li
# ..                   ...        ...     ...                ...
# 437            Liu Yifei   122503.0     1.0          Hua Mulan
# 438               Jet Li     1336.0     2.0        The Emperor
# 439           Mariya Ise  1250465.0     1.0      Beros (voice)
# 440      Andrew Garfield    37625.0     2.0    Desmond T. Doss
# 441         Vince Vaughn     4937.0     2.0    Sergeant Howell
#
#      actor_popularity  movie_id
# 0              29.914    566525
# 1              44.166    566525
# 2              45.392    566525
# 3              21.879    566525
# 4              10.809    566525
# ..                ...       ...
# 437            11.235    337401
# 438            12.942    337401
# 439            10.340    768744
# 440            33.885    324786
# 441            10.579    324786
#
# [442 rows x 6 columns]

# %%
directors = pd.DataFrame()
director_movie_id = []

for movie_id in titleNid['movie_id']:
    movie  = requests.get(f'https://api.themoviedb.org/3/movie/{movie_id}/credits?api_key={api_key}&language=en-US').json()
    for crew_member in movie['crew']:
        if crew_member['job'] == "Director":
            directors = directors.append(crew_member, ignore_index=True)
            director_movie_id.append(movie_id)

# %%
directors['movie_id'] = director_movie_id
directors = directors.rename(columns={'id': 'director_id', 'popularity': 'director_popularity'})
directors
# Out:
#      adult                 credit_id department  gender  director_id  \
# 0      0.0  5c8965e39251410cf7c195f6  Directing     2.0    1144604.0
# 1      0.0  5ba362e80e0a265e50015bba  Directing     2.0      87257.0
# 2      0.0  5e866a52a5743d00180fe64e  Directing     2.0       1333.0
# 3      0.0  5aecfbbb9251411d1e0022db  Directing     2.0     114404.0
# 4      0.0  5aac342192514116b10047e9  Directing     2.0      57633.0
# ..     ...                       ...        ...     ...          ...
# 215    0.0  5ffde78541a561003b063a37  Directing     0.0    2136790.0
# 216    0.0  5d53cc936dc6c0647b98881e  Directing     2.0     583166.0
# 217    0.0  6140bd2d56b9f7008b9a74e8  Directing     0.0    2925149.0
# 218    0.0  5f58be055b124000379051a6  Directing     0.0    1381895.0
# 219    0.0  5f58bdd97a97ab00349f3ff2  Directing     2.0    1994928.0
#
#           job known_for_department                     name  \
# 0    Director            Directing    Destin Daniel Cretton
# 1    Director            Directing       Cary Joji Fukunaga
# 2    Director               Acting              Andy Serkis
# 3    Director            Directing         Miguel Sapochnik
# 4    Director            Directing  Rawson Marshall Thurber
# ..        ...                  ...                      ...
# 215  Director                  Art             Dave Needham
# 216  Director            Directing              Kim Ji-hoon
# 217  Director               Acting            Sean Bichimer
# 218  Director            Directing              Dan Abraham
# 219  Director       Visual Effects             Trent Correy
#
#                original_name  director_popularity  \
# 0      Destin Daniel Cretton                5.834
# 1         Cary Joji Fukunaga                5.507
# 2                Andy Serkis               11.556
# 3           Miguel Sapochnik                2.812
# 4    Rawson Marshall Thurber                6.960
# ..                       ...                  ...
# 215             Dave Needham                0.600
# 216              Kim Ji-hoon                2.060
# 217            Sean Bichimer                0.600
# 218              Dan Abraham                0.600
# 219             Trent Correy                0.600
#
#                          profile_path  movie_id
# 0    /6pOwxAXGsaqjlJmAdz9k3UArBdS.jpg    566525
# 1    /qhrtYCUM2NEaqVP3oB7vqkOTpx0.jpg    370172
# 2    /2aJLwOQK50Lx7PvIHGW1GMytTOL.jpg    580489
# 3    /jlZGTjiifvvFDoEtlwrKz7QxuJS.jpg    522402
# 4    /4gpzB12oy73qr5nWNNyZICz9nFB.jpg    512195
# ..                                ...       ...
# 215                              None    410113
# 216  /eJr6Bzo45mR8CDCrecjYpJIZObz.jpg    623135
# 217                              None    874209
# 218                              None    741074
# 219  /kzaOz9jtkFg9YcyvGO5CUOdf1fF.jpg    741074
#
# [220 rows x 12 columns]

# %%
director_clean = directors[['name','director_id','gender','director_popularity','movie_id']]
director_clean
# Out:
#                         name  director_id  gender  director_popularity  \
# 0      Destin Daniel Cretton    1144604.0     2.0                5.834
# 1         Cary Joji Fukunaga      87257.0     2.0                5.507
# 2                Andy Serkis       1333.0     2.0               11.556
# 3           Miguel Sapochnik     114404.0     2.0                2.812
# 4    Rawson Marshall Thurber      57633.0     2.0                6.960
# ..                       ...          ...     ...                  ...
# 215             Dave Needham    2136790.0     0.0                0.600
# 216              Kim Ji-hoon     583166.0     2.0                2.060
# 217            Sean Bichimer    2925149.0     0.0                0.600
# 218              Dan Abraham    1381895.0     0.0                0.600
# 219             Trent Correy    1994928.0     2.0                0.600
#
#      movie_id
# 0      566525
# 1      370172
# 2      580489
# 3      522402
# 4      512195
# ..        ...
# 215    410113
# 216    623135
# 217    874209
# 218    741074
# 219    741074
#
# [220 rows x 5 columns]

# %%
famous_actors_cleaned.to_csv("Tables/Actors.csv")
director_clean.to_csv("Tables/Directors.csv")
