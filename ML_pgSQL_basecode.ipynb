# %%
import pandas as pd
import psycopg2
from postgres_data import host
from postgres_data import password
from postgres_data import user
from sqlalchemy import create_engine

# %%
# Create an engine instance

alchemyEngine = create_engine(f'postgresql://{user}:{password}@{host}:5432/Movie_Data')

# %%
# Connect to PostgreSQL server
dbConnection = alchemyEngine.connect()

# Read data from PostgreSQL database table and load into a DataFrame instance
df = pd.read_sql("select * from meta", dbConnection)
dbConnection.close()
df.head()
# Out:
#    movie_id                                     title release_date  \
# 0       671  Harry Potter and the Philosopher's Stone   2001-11-16
# 1       671  Harry Potter and the Philosopher's Stone   2001-11-16
# 2       671  Harry Potter and the Philosopher's Stone   2001-11-16
# 3       671  Harry Potter and the Philosopher's Stone   2001-11-16
# 4       671  Harry Potter and the Philosopher's Stone   2001-11-16
#
#    movie_popularity  vote_average  vote_count     budget    revenue ratings  \
# 0           305.856           7.9       21398  125000000  976475550      PG
# 1           305.856           7.9       21398  125000000  976475550      PG
# 2           305.856           7.9       21398  125000000  976475550      PG
# 3           305.856           7.9       21398  125000000  976475550      PG
# 4           305.856           7.9       21398  125000000  976475550      PG
#
#     actor_name  ...  actor_gender         character actor_popularity  \
# 0  Emma Watson  ...           1.0  Hermione Granger           16.930
# 1  Emma Watson  ...           1.0  Hermione Granger           16.930
# 2   Tom Felton  ...           2.0      Draco Malfoy           10.918
# 3   Tom Felton  ...           2.0      Draco Malfoy           10.918
# 4   Tom Felton  ...           2.0      Draco Malfoy           10.918
#
#     director_name director_id  director_gender  director_popularity  \
# 0  Chris Columbus     10965.0              2.0                2.589
# 1  Chris Columbus     10965.0              2.0                2.589
# 2  Chris Columbus     10965.0              2.0                2.589
# 3  Chris Columbus     10965.0              2.0                2.589
# 4  Chris Columbus     10965.0              2.0                2.589
#
#    studio_id            studio_name origin_country
# 0      436.0          1492 Pictures             US
# 1      174.0  Warner Bros. Pictures             US
# 2      436.0          1492 Pictures             US
# 3      437.0           Heyday Films             GB
# 4      174.0  Warner Bros. Pictures             US
#
# [5 rows x 21 columns]
